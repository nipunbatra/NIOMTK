# %%
import numpy as np
import pandas as pd
from numpy import *
from pandas import *
import matplotlib
import os
import os.path
from os import *
from os.path import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dir_path='/Users/rishi/Documents/Master_folder/IIITD/6th_semester/BTP/NIOMTK_datasets'

# %%
store=HDFStore(join(dir_path, 'eco.h5'))

# %%
df=store['/building2/elec/meter2']
mean_df=df.resample('15min', how='mean' )
median_df=df.resample('15min', how='median')
std_df=df.resample('15min', how=np.std)

# %%
range_df=df.resample('15min', how=np.max) - df.resample('15min', how=np.min)

# %%
mean_df # for the sake of completeness
# Out:
#                                 power   current     voltage  phase_angle  \
#                                active
# 2012-06-01 02:00:00+02:00   21.157919  0.157437  235.039993     0.000000
# 2012-06-01 02:15:00+02:00   21.159485  0.156040  235.156662     0.000000
# 2012-06-01 02:30:00+02:00   21.194288  0.157210  235.328888     0.000000
# 2012-06-01 02:45:00+02:00   21.209436  0.156509  236.002228     0.000000
# 2012-06-01 03:00:00+02:00   21.127615  0.156815  234.485550     0.000000
# 2012-06-01 03:15:00+02:00   21.163544  0.157945  234.991104     0.000000
# 2012-06-01 03:30:00+02:00   21.191628  0.157052  235.512222     0.000000
# 2012-06-01 03:45:00+02:00   21.239378  0.156522  236.228882     0.000000
# 2012-06-01 04:00:00+02:00   21.224619  0.156389  235.955551     0.000000
# 2012-06-01 04:15:00+02:00   21.232401  0.155822  236.277771     0.000000
# 2012-06-01 04:30:00+02:00   21.233612  0.155504  236.022217     0.000000
# ...

# %%
mean_df['power']['active']
# Out:
# 2012-06-01 02:00:00+02:00    21.157919
# 2012-06-01 02:15:00+02:00    21.159485
# 2012-06-01 02:30:00+02:00    21.194288
# 2012-06-01 02:45:00+02:00    21.209436
# 2012-06-01 03:00:00+02:00    21.127615
# 2012-06-01 03:15:00+02:00    21.163544
# 2012-06-01 03:30:00+02:00    21.191628
# 2012-06-01 03:45:00+02:00    21.239378
# 2012-06-01 04:00:00+02:00    21.224619
# 2012-06-01 04:15:00+02:00    21.232401
# 2012-06-01 04:30:00+02:00    21.233612
# 2012-06-01 04:45:00+02:00    21.220615
# 2012-06-01 05:00:00+02:00    21.185457
# 2012-06-01 05:15:00+02:00    21.141870
# 2012-06-01 05:30:00+02:00    21.165274
# ...
# 2013-01-31 21:15:00+01:00    21.676968
# 2013-01-31 21:30:00+01:00    21.697123
# 2013-01-31 21:45:00+01:00    21.674263
# 2013-01-31 22:00:00+01:00    21.614031
# 2013-01-31 22:15:00+01:00    21.579420
# 2013-01-31 22:30:00+01:00    21.583349
# 2013-01-31 22:45:00+01:00    21.603861
# 2013-01-31 23:00:00+01:00    21.625687
# 2013-01-31 23:15:00+01:00    21.561872
# ...

# %%
median_df
# Out:
#                                 power  current  voltage  phase_angle  \
#                                active
# 2012-06-01 04:30:00+02:00    0.945999
# 2012-06-01 04:45:00+02:00    0.889002
# 2012-06-01 05:00:00+02:00    0.790001
# 2012-06-01 05:15:00+02:00    0.885000
# 2012-06-01 05:30:00+02:00    0.851002
# ...
# 2013-01-31 21:15:00+01:00    0.897999
# 2013-01-31 21:30:00+01:00    0.923000
# 2013-01-31 21:45:00+01:00    0.997000
# 2013-01-31 22:00:00+01:00    1.016001
# 2013-01-31 22:15:00+01:00    1.067999
# 2013-01-31 22:30:00+01:00    0.945000
# 2013-01-31 22:45:00+01:00    0.941000
# 2013-01-31 23:00:00+01:00    1.134001
# 2013-01-31 23:15:00+01:00    1.101000
# ...

# %%
mean_df['power']['active'].plot()

# %%
mean_df['power']['active'].plot(kind='hist')

# %%
mean_df['power']['active'][:96]
# Out:
# 2012-06-01 02:00:00+02:00    21.157919
# 2012-06-01 02:15:00+02:00    21.159485
# 2012-06-01 02:30:00+02:00    21.194288
# 2012-06-01 02:45:00+02:00    21.209436
# 2012-06-01 03:00:00+02:00    21.127615
# 2012-06-01 03:15:00+02:00    21.163544
# 2012-06-01 03:30:00+02:00    21.191628
# 2012-06-01 03:45:00+02:00    21.239378
# 2012-06-01 04:00:00+02:00    21.224619
# 2012-06-01 04:15:00+02:00    21.232401
# 2012-06-01 04:30:00+02:00    21.233612
# 2012-06-01 04:45:00+02:00    21.220615
# 2012-06-01 05:00:00+02:00    21.185457
# 2012-06-01 05:15:00+02:00    21.141870
# 2012-06-01 05:30:00+02:00    21.165274
# ...
# 2012-06-01 22:15:00+02:00    230.306564
# 2012-06-01 22:30:00+02:00    230.292099
# 2012-06-01 22:45:00+02:00    229.744476
# 2012-06-01 23:00:00+02:00    229.930969
# 2012-06-01 23:15:00+02:00    230.231888
# 2012-06-01 23:30:00+02:00    229.816284
# 2012-06-01 23:45:00+02:00    230.402573
# 2012-06-02 00:00:00+02:00    230.083740
# 2012-06-02 00:15:00+02:00    170.924911
# ...

# %%
mean_df['power']['active'][:96].plot(kind = 'hist')

# %%
mean_df['power']['active'][:96].plot() #Day 1

# %%
mean_df['power']['active'][96:192].plot() #Day 2

# %%
mean_df['power']['active'][192:(192 + 96)].plot(kind = 'hist')

# %%
mean_df['power']['active'][192:(192 + 96)].plot()

# %%
for i in range (286, 1000, 96):
    mean_df['power']['active'][i:i+96].plot()

# %%
for i in range (0, 1000, 96):
    mean_df['power']['active'][i:i+96].plot()

# %%
for i in range (286, 1000, 96):
    median_df['power']['active'][i:i+96].plot()

# %%
for i in range (286, 1000, 96):
    std_df['power']['active'][i:i+96].plot()

# %%
for i in range (286, 1000, 96):
    range_df['power']['active'][i:i+96].plot()
