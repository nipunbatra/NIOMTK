# %%
import numpy as np
import pandas as pd
from numpy import *
from pandas import *
import matplotlib
import os
import os.path
from os import *
from os.path import *
# %matplotlib inline

# %%
dir_path='/Users/rishi/Documents/Master_folder/IIITD/6th_semester/BTP/NIOMTK_datasets'

# %%
store=HDFStore(join(dir_path, 'eco.h5'))

# %%
store

# %%
df=store['/building2/elec/meter2']

# %%
mean_df=df.rescale('15min', how='mean')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-df1e709f1fcc> in <module>()
# ----> 1 mean_df=df.rescale('15min', how='mean')
#
# /Users/rishi/anaconda/lib/python2.7/site-packages/pandas-0.14.1_345_ge226bac-py2.7-macosx-10.5-x86_64.egg/pandas/core/generic.pyc in __getattr__(self, name)
#    1916                 return self[name]
#    1917             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1918                                  (type(self).__name__, name))
#    1919
#    1920     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'rescale'

# %%
mean_df=df.resample('15min', how='mean')

# %%
std_df=df.resample('15min', how=np.std)

# %%
max_df=df.max()

# %%
min_df=df.min()

# %%
range_df=df.max() - df.min()

# %%
import matplotlib.pyplot as plt

# %%
mean_df.plot()

# %%
std_df.plot()

# %%
range_df.plot()

# %%
fig=plt.figure()

# %%
ax1=fig.add_subplot(2, 2, 1)

# %%
plt.plot(mean_df, 'k--')

# %%
ax2=fig.add_subplot(2, 2, 2)

# %%
mean_df.plot( color='k', linestyle='dashed', marker='o')

# %%
plt.plot(mean_df, 'k--')

# %%
plt.plot(mean_df, 'k-')

# %%
df.resample('15min', how=np.max)
# Out:
#                                 power  current  voltage  phase_angle  \
#                                active
# 2012-06-01 02:00:00+02:00   21.576000   0.1656      236            0
# 2012-06-01 02:15:00+02:00   21.556999   0.1586      236            0
# 2012-06-01 02:30:00+02:00   21.561001   0.1749      236            0
# 2012-06-01 02:45:00+02:00   21.650999   0.1601      237            0
# 2012-06-01 03:00:00+02:00   21.552000   0.1645      236            0
# 2012-06-01 03:15:00+02:00   21.566000   0.1726      236            0
# 2012-06-01 03:30:00+02:00   21.698000   0.1590      236            0
# 2012-06-01 03:45:00+02:00   21.604000   0.1736      237            0
# 2012-06-01 04:00:00+02:00   21.656000   0.1639      237            0
# 2012-06-01 04:15:00+02:00   21.679001   0.1582      237            0
# 2012-06-01 04:30:00+02:00   21.698000   0.1736      237            0
# 2012-06-01 04:45:00+02:00   21.599001   0.1575      237            0
# ...

# %%
df_max=df.resample('15min', how=np.max)

# %%
df_min=df.resample('15min', how=np.min)

# %%
df_range=df_max - df_min

# %%
df_range
# Out:
#                                 power  current  voltage  phase_angle  \
#                                active
# 2012-06-01 02:00:00+02:00    1.040001   0.0140        1            0
# 2012-06-01 02:15:00+02:00    1.007000   0.0080        2            0
# 2012-06-01 02:30:00+02:00    0.837000   0.0207        2            0
# 2012-06-01 02:45:00+02:00    0.893999   0.0070        2            0
# 2012-06-01 03:00:00+02:00    0.875000   0.0112        3            0
# 2012-06-01 03:15:00+02:00    1.063000   0.0184        2            0
# 2012-06-01 03:30:00+02:00    0.969000   0.0057        1            0
# 2012-06-01 03:45:00+02:00    0.813999   0.0205        1            0
# 2012-06-01 04:00:00+02:00    0.979000   0.0110        2            0
# 2012-06-01 04:15:00+02:00    0.908001   0.0055        2            0
# 2012-06-01 04:30:00+02:00    0.945999   0.0223        2            0
# 2012-06-01 04:45:00+02:00    0.889002   0.0055        2            0
# ...

# %%
fig1=plt.figure()

# %%
ax1=fig.add_subplot(2, 2, 1)

# %%
ax2=fig.add_subplot(2, 2, 2)

# %%
ax3=fig.add_subplot(2, 2, 3)

# %%
plt.plot(df_max)

# %%
fig

# %%
ax2.plot(df_min)

# %%
ax3.plot(df_range)

# %%
fig

# %%
mean_df
# Out:
#                                 power   current     voltage  phase_angle  \
#                                active
# 2012-06-01 02:00:00+02:00   21.157919  0.157437  235.039993     0.000000
# 2012-06-01 02:15:00+02:00   21.159485  0.156040  235.156662     0.000000
# 2012-06-01 02:30:00+02:00   21.194288  0.157210  235.328888     0.000000
# 2012-06-01 02:45:00+02:00   21.209436  0.156509  236.002228     0.000000
# 2012-06-01 03:00:00+02:00   21.127615  0.156815  234.485550     0.000000
# 2012-06-01 03:15:00+02:00   21.163544  0.157945  234.991104     0.000000
# 2012-06-01 03:30:00+02:00   21.191628  0.157052  235.512222     0.000000
# 2012-06-01 03:45:00+02:00   21.239378  0.156522  236.228882     0.000000
# 2012-06-01 04:00:00+02:00   21.224619  0.156389  235.955551     0.000000
# 2012-06-01 04:15:00+02:00   21.232401  0.155822  236.277771     0.000000
# 2012-06-01 04:30:00+02:00   21.233612  0.155504  236.022217     0.000000
# ...

# %%
std_df
# Out:
#                                power   current   voltage  phase_angle  \
#                               active
# 2012-06-01 02:00:00+02:00   0.144644  0.001985       NaN     0.000000
# 2012-06-01 02:15:00+02:00   0.140201  0.001313       NaN     0.000000
# 2012-06-01 02:30:00+02:00   0.134441  0.001503       NaN     0.000000
# 2012-06-01 02:45:00+02:00   0.143547  0.000810  0.000000     0.000000
# 2012-06-01 03:00:00+02:00   0.132813  0.000893  0.301867     0.000000
# 2012-06-01 03:15:00+02:00   0.144781  0.001436  0.498055     0.000000
# 2012-06-01 03:30:00+02:00   0.134147  0.000875       NaN     0.000000
# 2012-06-01 03:45:00+02:00   0.139068  0.001621       NaN     0.000000
# 2012-06-01 04:00:00+02:00   0.133259  0.001144  0.142301     0.000000
# 2012-06-01 04:15:00+02:00   0.139352  0.000878  0.369710     0.000000
# 2012-06-01 04:30:00+02:00   0.137063  0.001912  0.000000     0.000000
# 2012-06-01 04:45:00+02:00   0.138926  0.000737  0.071151     0.000000
# ...

# %%
std_df['power']
# Out:
#                               active   reactive
# 2012-06-01 02:00:00+02:00   0.144644   0.000000
# 2012-06-01 02:15:00+02:00   0.140201   0.000000
# 2012-06-01 02:30:00+02:00   0.134441   0.000000
# 2012-06-01 02:45:00+02:00   0.143547   0.000000
# 2012-06-01 03:00:00+02:00   0.132813   0.000000
# 2012-06-01 03:15:00+02:00   0.144781   0.000000
# 2012-06-01 03:30:00+02:00   0.134147   0.000000
# 2012-06-01 03:45:00+02:00   0.139068   0.000000
# 2012-06-01 04:00:00+02:00   0.133259   0.000000
# 2012-06-01 04:15:00+02:00   0.139352   0.000000
# 2012-06-01 04:30:00+02:00   0.137063   0.000000
# 2012-06-01 04:45:00+02:00   0.138926   0.000000
# 2012-06-01 05:00:00+02:00   0.131014   0.000000
# 2012-06-01 05:15:00+02:00   0.137639   0.000000
# 2012-06-01 05:30:00+02:00   0.134882   0.000000
# 2012-06-01 05:45:00+02:00   0.132813   0.000000
# 2012-06-01 06:00:00+02:00   0.141744   0.000000
# 2012-06-01 06:15:00+02:00   0.131917   0.000000
# 2012-06-01 06:30:00+02:00   0.141465   0.000000
# ...

# %%
std_df['power']['active']
# Out:
# 2012-06-01 02:00:00+02:00    0.144644
# 2012-06-01 02:15:00+02:00    0.140201
# 2012-06-01 02:30:00+02:00    0.134441
# 2012-06-01 02:45:00+02:00    0.143547
# 2012-06-01 03:00:00+02:00    0.132813
# 2012-06-01 03:15:00+02:00    0.144781
# 2012-06-01 03:30:00+02:00    0.134147
# 2012-06-01 03:45:00+02:00    0.139068
# 2012-06-01 04:00:00+02:00    0.133259
# 2012-06-01 04:15:00+02:00    0.139352
# 2012-06-01 04:30:00+02:00    0.137063
# 2012-06-01 04:45:00+02:00    0.138926
# 2012-06-01 05:00:00+02:00    0.131014
# 2012-06-01 05:15:00+02:00    0.137639
# 2012-06-01 05:30:00+02:00    0.134882
# ...
# 2013-01-31 21:15:00+01:00    0.154814
# 2013-01-31 21:30:00+01:00    0.158600
# 2013-01-31 21:45:00+01:00    0.158849
# 2013-01-31 22:00:00+01:00    0.152886
# 2013-01-31 22:15:00+01:00    0.162053
# 2013-01-31 22:30:00+01:00    0.150145
# 2013-01-31 22:45:00+01:00    0.162297
# 2013-01-31 23:00:00+01:00    0.169334
# 2013-01-31 23:15:00+01:00    0.158350
# ...

# %%
mean_df['power']['active']
# Out:
# 2012-06-01 02:00:00+02:00    21.157919
# 2012-06-01 02:15:00+02:00    21.159485
# 2012-06-01 02:30:00+02:00    21.194288
# 2012-06-01 02:45:00+02:00    21.209436
# 2012-06-01 03:00:00+02:00    21.127615
# 2012-06-01 03:15:00+02:00    21.163544
# 2012-06-01 03:30:00+02:00    21.191628
# 2012-06-01 03:45:00+02:00    21.239378
# 2012-06-01 04:00:00+02:00    21.224619
# 2012-06-01 04:15:00+02:00    21.232401
# 2012-06-01 04:30:00+02:00    21.233612
# 2012-06-01 04:45:00+02:00    21.220615
# 2012-06-01 05:00:00+02:00    21.185457
# 2012-06-01 05:15:00+02:00    21.141870
# 2012-06-01 05:30:00+02:00    21.165274
# ...
# 2013-01-31 21:15:00+01:00    21.676968
# 2013-01-31 21:30:00+01:00    21.697123
# 2013-01-31 21:45:00+01:00    21.674263
# 2013-01-31 22:00:00+01:00    21.614031
# 2013-01-31 22:15:00+01:00    21.579420
# 2013-01-31 22:30:00+01:00    21.583349
# 2013-01-31 22:45:00+01:00    21.603861
# 2013-01-31 23:00:00+01:00    21.625687
# 2013-01-31 23:15:00+01:00    21.561872
# ...

# %%
range_df['power']['active']
# Out:
# 2977.1111

# %%
df_range['power']['active']
# Out:
# 2012-06-01 02:00:00+02:00    1.040001
# 2012-06-01 02:15:00+02:00    1.007000
# 2012-06-01 02:30:00+02:00    0.837000
# 2012-06-01 02:45:00+02:00    0.893999
# 2012-06-01 03:00:00+02:00    0.875000
# 2012-06-01 03:15:00+02:00    1.063000
# 2012-06-01 03:30:00+02:00    0.969000
# 2012-06-01 03:45:00+02:00    0.813999
# 2012-06-01 04:00:00+02:00    0.979000
# 2012-06-01 04:15:00+02:00    0.908001
# 2012-06-01 04:30:00+02:00    0.945999
# 2012-06-01 04:45:00+02:00    0.889002
# 2012-06-01 05:00:00+02:00    0.790001
# 2012-06-01 05:15:00+02:00    0.885000
# 2012-06-01 05:30:00+02:00    0.851002
# ...
# 2013-01-31 21:15:00+01:00    0.897999
# 2013-01-31 21:30:00+01:00    0.923000
# 2013-01-31 21:45:00+01:00    0.997000
# 2013-01-31 22:00:00+01:00    1.016001
# 2013-01-31 22:15:00+01:00    1.067999
# 2013-01-31 22:30:00+01:00    0.945000
# 2013-01-31 22:45:00+01:00    0.941000
# 2013-01-31 23:00:00+01:00    1.134001
# 2013-01-31 23:15:00+01:00    1.101000
# ...

# %% [markdown]
# ######

# %%
threshold1=mean_df['power'].mean()

# %%
threshold1
# Out:
# active      86.546322
# reactive    -2.970587
# dtype: float64

# %%
threshold2=mean_df['power']['active'].mean()

# %%
threshold2
# Out:
# 86.546322275880101

# %%
mean_df > threshold2
# Out:
#                            power current voltage phase_angle    power
#                           active                             reactive
# 2012-06-01 02:00:00+02:00  False   False    True       False    False
# 2012-06-01 02:15:00+02:00  False   False    True       False    False
# 2012-06-01 02:30:00+02:00  False   False    True       False    False
# 2012-06-01 02:45:00+02:00  False   False    True       False    False
# 2012-06-01 03:00:00+02:00  False   False    True       False    False
# 2012-06-01 03:15:00+02:00  False   False    True       False    False
# 2012-06-01 03:30:00+02:00  False   False    True       False    False
# 2012-06-01 03:45:00+02:00  False   False    True       False    False
# 2012-06-01 04:00:00+02:00  False   False    True       False    False
# 2012-06-01 04:15:00+02:00  False   False    True       False    False
# 2012-06-01 04:30:00+02:00  False   False    True       False    False
# ...

# %%
mean_df['power']['active'] > threshold2
# Out:
# 2012-06-01 02:00:00+02:00    False
# 2012-06-01 02:15:00+02:00    False
# 2012-06-01 02:30:00+02:00    False
# 2012-06-01 02:45:00+02:00    False
# 2012-06-01 03:00:00+02:00    False
# 2012-06-01 03:15:00+02:00    False
# 2012-06-01 03:30:00+02:00    False
# 2012-06-01 03:45:00+02:00    False
# 2012-06-01 04:00:00+02:00    False
# 2012-06-01 04:15:00+02:00    False
# 2012-06-01 04:30:00+02:00    False
# 2012-06-01 04:45:00+02:00    False
# 2012-06-01 05:00:00+02:00    False
# 2012-06-01 05:15:00+02:00    False
# 2012-06-01 05:30:00+02:00    False
# ...
# 2013-01-31 21:15:00+01:00    False
# 2013-01-31 21:30:00+01:00    False
# 2013-01-31 21:45:00+01:00    False
# 2013-01-31 22:00:00+01:00    False
# 2013-01-31 22:15:00+01:00    False
# 2013-01-31 22:30:00+01:00    False
# 2013-01-31 22:45:00+01:00    False
# 2013-01-31 23:00:00+01:00    False
# 2013-01-31 23:15:00+01:00    False
# 2013-01-31 23:30:00+01:00    False
# 2013-01-31 23:45:00+01:00    False
# ...

# %%
arr_mean=mean_df.reset_index().values

# %%
arr_mean
# Out:
# array([[Timestamp('2012-06-01 02:00:00+0200', tz='Europe/Berlin', offset='15T'),
#         21.15791893005371, 0.15743675827980042, 235.0399932861328, 0.0, 0.0],
#        [Timestamp('2012-06-01 02:15:00+0200', tz='Europe/Berlin', offset='15T'),
#         21.15948486328125, 0.15604045987129211, 235.1566619873047, 0.0, 0.0],
#        [Timestamp('2012-06-01 02:30:00+0200', tz='Europe/Berlin', offset='15T'),
#         21.19428825378418, 0.15720966458320618, 235.32888793945312, 0.0,
#         0.0],
#        ...,
#        [Timestamp('2013-02-01 00:15:00+0100', tz='Europe/Berlin', offset='15T'),
#         21.672895431518555, 0.15837162733078003, 236.94888305664062, 0.0,
#         0.0],
#        [Timestamp('2013-02-01 00:30:00+0100', tz='Europe/Berlin', offset='15T'),
#         21.693756103515625, 0.1579974889755249, 237.16111755371094, 0.0,
#         0.0],
#        [Timestamp('2013-02-01 00:45:00+0100', tz='Europe/Berlin', offset='15T'),
# ...

# %%
mean_df['power']['active']
# Out:
# 2012-06-01 02:00:00+02:00    21.157919
# 2012-06-01 02:15:00+02:00    21.159485
# 2012-06-01 02:30:00+02:00    21.194288
# 2012-06-01 02:45:00+02:00    21.209436
# 2012-06-01 03:00:00+02:00    21.127615
# 2012-06-01 03:15:00+02:00    21.163544
# 2012-06-01 03:30:00+02:00    21.191628
# 2012-06-01 03:45:00+02:00    21.239378
# 2012-06-01 04:00:00+02:00    21.224619
# 2012-06-01 04:15:00+02:00    21.232401
# 2012-06-01 04:30:00+02:00    21.233612
# 2012-06-01 04:45:00+02:00    21.220615
# 2012-06-01 05:00:00+02:00    21.185457
# 2012-06-01 05:15:00+02:00    21.141870
# 2012-06-01 05:30:00+02:00    21.165274
# ...
# 2013-01-31 21:15:00+01:00    21.676968
# 2013-01-31 21:30:00+01:00    21.697123
# 2013-01-31 21:45:00+01:00    21.674263
# 2013-01-31 22:00:00+01:00    21.614031
# 2013-01-31 22:15:00+01:00    21.579420
# 2013-01-31 22:30:00+01:00    21.583349
# 2013-01-31 22:45:00+01:00    21.603861
# 2013-01-31 23:00:00+01:00    21.625687
# 2013-01-31 23:15:00+01:00    21.561872
# ...

# %%
mean_df['power']['active'].values
# Out:
# array([ 21.15791893,  21.15948486,  21.19428825, ...,  21.67289543,
#         21.6937561 ,  21.64632034], dtype=float32)

# %%
mean_arr=mean_df['power']['active'].values

# %%
sum(mean_arr)/len(mean_arr)
# Out:
# nan

# %%
sum(mean_arr)
# Out:
# nan

# %%
mean_arr
# Out:
# array([ 21.15791893,  21.15948486,  21.19428825, ...,  21.67289543,
#         21.6937561 ,  21.64632034], dtype=float32)

# %%
np.mean(mean_arr[1:20])
# Out:
# 21.202307

# %%
sum=0
for i in mean_arr:
    print (i)
    print (sum)
    sum = sum + (i/len(mean_arr))
# Out:
# 21.1579
# 0
# 21.1595
# 0.000899571383081
# 21.1943
# 0.00179920934495
# 21.2094
# 0.00270032704282
# 21.1276
# 0.00360208879523
# 21.1635
# 0.00450037174484
# 21.1916
# 0.00540018227636
# 21.2394
# 0.00630118684704
# 21.2246
# 0.00720422162491
# 21.2324
# 0.00810662889156
# 21.2336
# 0.00900936702482
# 21.2206
# 0.00991215665324
# 21.1855
# 0.010814393702
# 21.1419
# 0.0117151359312
# 21.1653
# 0.012614024983
# 21.2157
# 0.0135139090674
# 21.2637
# 0.0144159380271
# 21.2518
# 0.0153200064387
# 21.2224
# 0.016223571414
# 21.201
# 0.0171258831511
# 21.1375
# 0.0180272849239
# 21.151
# 0.0189259892418
# 21.1122
# 0.0198252666564
# 21.1245
# 0.0207228960634
# 21.2105
# 0.0216210473151
# 21.1735
# 0.0225228543995
# 21.7044
# 0.0234230863805
# 21.4444
# 0.0243458940058
# 21.6504
# 0.0252576473619
# 21.7274
# 0.0261781581405
# 199.304
# 0.0271019413358
# 231.782
# 0.0355757521934
# 231.437
# 0.0454304484283
# 231.413
# 0.0552704522399
# 231.351
# 0.0651094225799
# 231.062
# ...

# %%
sum
# Out:
# nan

# %%
from scipy.stats.stats import nanmean

# %%
mdat=np.ma.masked_array(mean_df, np.isnan(mean_df))

# %%
threshold1=np.mean(mdat, axis=1)

# %%
threshold1
# Out:
# masked_array(data = [51.2710693359375 51.294439697265624 51.33607788085938 ...,
#  51.7560302734375 51.80257568359375 51.63729248046875],
#              mask = [False False False ..., False False False],
#        fill_value = 1e+20)

# %%
threshold1.filled(np.nan)
# Out:
# array([ 51.27106934,  51.2944397 ,  51.33607788, ...,  51.75603027,
#         51.80257568,  51.63729248])

# %%
np.isnan(mean_arr)
# Out:
# array([False, False, False, ..., False, False, False], dtype=bool)

# %%
True in np.isnan(mean_arr)
# Out:
# True

# %%
mean_arr[~np.isnan(mean_arr)].mean()
# Out:
# 86.546318

# %%
threshold_mean=mean_arr[~np.isnan(mean_arr)].mean()

# %%
mean_df['power']['active'] > threshold_mean
# Out:
# 2012-06-01 02:00:00+02:00    False
# 2012-06-01 02:15:00+02:00    False
# 2012-06-01 02:30:00+02:00    False
# 2012-06-01 02:45:00+02:00    False
# 2012-06-01 03:00:00+02:00    False
# 2012-06-01 03:15:00+02:00    False
# 2012-06-01 03:30:00+02:00    False
# 2012-06-01 03:45:00+02:00    False
# 2012-06-01 04:00:00+02:00    False
# 2012-06-01 04:15:00+02:00    False
# 2012-06-01 04:30:00+02:00    False
# 2012-06-01 04:45:00+02:00    False
# 2012-06-01 05:00:00+02:00    False
# 2012-06-01 05:15:00+02:00    False
# 2012-06-01 05:30:00+02:00    False
# ...
# 2013-01-31 21:15:00+01:00    False
# 2013-01-31 21:30:00+01:00    False
# 2013-01-31 21:45:00+01:00    False
# 2013-01-31 22:00:00+01:00    False
# 2013-01-31 22:15:00+01:00    False
# 2013-01-31 22:30:00+01:00    False
# 2013-01-31 22:45:00+01:00    False
# 2013-01-31 23:00:00+01:00    False
# 2013-01-31 23:15:00+01:00    False
# 2013-01-31 23:30:00+01:00    False
# 2013-01-31 23:45:00+01:00    False
# ...

# %%
threshold_std = std_df['power']['active'].mean()

# %%
threshold_std
# Out:
# 14.65895194488643

# %%
threshold_range=df_range['power']['active'].mean()

# %%
threshold_range
# Out:
# 50.059339865771207

# %%
std_df['power']['active'] > threshold_std
# Out:
# 2012-06-01 02:00:00+02:00    False
# 2012-06-01 02:15:00+02:00    False
# 2012-06-01 02:30:00+02:00    False
# 2012-06-01 02:45:00+02:00    False
# 2012-06-01 03:00:00+02:00    False
# 2012-06-01 03:15:00+02:00    False
# 2012-06-01 03:30:00+02:00    False
# 2012-06-01 03:45:00+02:00    False
# 2012-06-01 04:00:00+02:00    False
# 2012-06-01 04:15:00+02:00    False
# 2012-06-01 04:30:00+02:00    False
# 2012-06-01 04:45:00+02:00    False
# 2012-06-01 05:00:00+02:00    False
# 2012-06-01 05:15:00+02:00    False
# 2012-06-01 05:30:00+02:00    False
# ...
# 2013-01-31 21:15:00+01:00    False
# 2013-01-31 21:30:00+01:00    False
# 2013-01-31 21:45:00+01:00    False
# 2013-01-31 22:00:00+01:00    False
# 2013-01-31 22:15:00+01:00    False
# 2013-01-31 22:30:00+01:00    False
# 2013-01-31 22:45:00+01:00    False
# 2013-01-31 23:00:00+01:00    False
# 2013-01-31 23:15:00+01:00    False
# 2013-01-31 23:30:00+01:00    False
# 2013-01-31 23:45:00+01:00    False
# ...

# %%
df_range['power']['active'] > threshold_range
# Out:
# 2012-06-01 02:00:00+02:00    False
# 2012-06-01 02:15:00+02:00    False
# 2012-06-01 02:30:00+02:00    False
# 2012-06-01 02:45:00+02:00    False
# 2012-06-01 03:00:00+02:00    False
# 2012-06-01 03:15:00+02:00    False
# 2012-06-01 03:30:00+02:00    False
# 2012-06-01 03:45:00+02:00    False
# 2012-06-01 04:00:00+02:00    False
# 2012-06-01 04:15:00+02:00    False
# 2012-06-01 04:30:00+02:00    False
# 2012-06-01 04:45:00+02:00    False
# 2012-06-01 05:00:00+02:00    False
# 2012-06-01 05:15:00+02:00    False
# 2012-06-01 05:30:00+02:00    False
# ...
# 2013-01-31 21:15:00+01:00    False
# 2013-01-31 21:30:00+01:00    False
# 2013-01-31 21:45:00+01:00    False
# 2013-01-31 22:00:00+01:00    False
# 2013-01-31 22:15:00+01:00    False
# 2013-01-31 22:30:00+01:00    False
# 2013-01-31 22:45:00+01:00    False
# 2013-01-31 23:00:00+01:00    False
# 2013-01-31 23:15:00+01:00    False
# 2013-01-31 23:30:00+01:00    False
# 2013-01-31 23:45:00+01:00    False
# ...

# %%
std_series = std_df['power']['active'] > threshold_std

# %%
mean_series=mean_df['power']['active'] > threshold_mean

# %%
mean_series
# Out:
# 2012-06-01 02:00:00+02:00    False
# 2012-06-01 02:15:00+02:00    False
# 2012-06-01 02:30:00+02:00    False
# 2012-06-01 02:45:00+02:00    False
# 2012-06-01 03:00:00+02:00    False
# 2012-06-01 03:15:00+02:00    False
# 2012-06-01 03:30:00+02:00    False
# 2012-06-01 03:45:00+02:00    False
# 2012-06-01 04:00:00+02:00    False
# 2012-06-01 04:15:00+02:00    False
# 2012-06-01 04:30:00+02:00    False
# 2012-06-01 04:45:00+02:00    False
# 2012-06-01 05:00:00+02:00    False
# 2012-06-01 05:15:00+02:00    False
# 2012-06-01 05:30:00+02:00    False
# ...
# 2013-01-31 21:15:00+01:00    False
# 2013-01-31 21:30:00+01:00    False
# 2013-01-31 21:45:00+01:00    False
# 2013-01-31 22:00:00+01:00    False
# 2013-01-31 22:15:00+01:00    False
# 2013-01-31 22:30:00+01:00    False
# 2013-01-31 22:45:00+01:00    False
# 2013-01-31 23:00:00+01:00    False
# 2013-01-31 23:15:00+01:00    False
# 2013-01-31 23:30:00+01:00    False
# 2013-01-31 23:45:00+01:00    False
# ...

# %%
std_series
# Out:
# 2012-06-01 02:00:00+02:00    False
# 2012-06-01 02:15:00+02:00    False
# 2012-06-01 02:30:00+02:00    False
# 2012-06-01 02:45:00+02:00    False
# 2012-06-01 03:00:00+02:00    False
# 2012-06-01 03:15:00+02:00    False
# 2012-06-01 03:30:00+02:00    False
# 2012-06-01 03:45:00+02:00    False
# 2012-06-01 04:00:00+02:00    False
# 2012-06-01 04:15:00+02:00    False
# 2012-06-01 04:30:00+02:00    False
# 2012-06-01 04:45:00+02:00    False
# 2012-06-01 05:00:00+02:00    False
# 2012-06-01 05:15:00+02:00    False
# 2012-06-01 05:30:00+02:00    False
# ...
# 2013-01-31 21:15:00+01:00    False
# 2013-01-31 21:30:00+01:00    False
# 2013-01-31 21:45:00+01:00    False
# 2013-01-31 22:00:00+01:00    False
# 2013-01-31 22:15:00+01:00    False
# 2013-01-31 22:30:00+01:00    False
# 2013-01-31 22:45:00+01:00    False
# 2013-01-31 23:00:00+01:00    False
# 2013-01-31 23:15:00+01:00    False
# 2013-01-31 23:30:00+01:00    False
# 2013-01-31 23:45:00+01:00    False
# ...

# %%
range_series=df_range['power']['active'] > threshold_range

# %%
range_series
# Out:
# 2012-06-01 02:00:00+02:00    False
# 2012-06-01 02:15:00+02:00    False
# 2012-06-01 02:30:00+02:00    False
# 2012-06-01 02:45:00+02:00    False
# 2012-06-01 03:00:00+02:00    False
# 2012-06-01 03:15:00+02:00    False
# 2012-06-01 03:30:00+02:00    False
# 2012-06-01 03:45:00+02:00    False
# 2012-06-01 04:00:00+02:00    False
# 2012-06-01 04:15:00+02:00    False
# 2012-06-01 04:30:00+02:00    False
# 2012-06-01 04:45:00+02:00    False
# 2012-06-01 05:00:00+02:00    False
# 2012-06-01 05:15:00+02:00    False
# 2012-06-01 05:30:00+02:00    False
# ...
# 2013-01-31 21:15:00+01:00    False
# 2013-01-31 21:30:00+01:00    False
# 2013-01-31 21:45:00+01:00    False
# 2013-01-31 22:00:00+01:00    False
# 2013-01-31 22:15:00+01:00    False
# 2013-01-31 22:30:00+01:00    False
# 2013-01-31 22:45:00+01:00    False
# 2013-01-31 23:00:00+01:00    False
# 2013-01-31 23:15:00+01:00    False
# 2013-01-31 23:30:00+01:00    False
# 2013-01-31 23:45:00+01:00    False
# ...

# %% [markdown]
# Plotting Occupancy Results
# --------------------

# %%
mean_series.plot()

# %%
std_series.plot()

# %%
range_series.plot()
