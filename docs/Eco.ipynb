# %%
import numpy as np
import pandas as pd
from numpy import *
from pandas import *
import matplotlib
import os
import os.path
from os import *
from os.path import *
# %matplotlib inline

# %%
dir_path='/Users/rishi/Documents/Master_folder/IIITD/6th_semester/BTP/NIOMTK_datasets'

# %%
store=HDFStore(join(dir_path, 'eco.h5'))

# %%
store

# %%
df=store['/building2/elec/meter2']

# %%
mean_df=df.rescale('15min', how='mean')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-df1e709f1fcc> in <module>()
# ----> 1 mean_df=df.rescale('15min', how='mean')
#
# /Users/rishi/anaconda/lib/python2.7/site-packages/pandas-0.14.1_345_ge226bac-py2.7-macosx-10.5-x86_64.egg/pandas/core/generic.pyc in __getattr__(self, name)
#    1916                 return self[name]
#    1917             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1918                                  (type(self).__name__, name))
#    1919
#    1920     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'rescale'

# %%
mean_df=df.resample('15min', how='mean')

# %%
std_df=df.resample('15min', how=np.std)

# %%
max_df=df.max()

# %%
min_df=df.min()

# %%
range_df=df.max() - df.min()

# %%
import matplotlib.pyplot as plt

# %%
mean_df.plot()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 141

# %%
std_df.plot()

# %%
range_df.plot()

# %%
fig=plt.figure()

# %%
ax1=fig.add_subplot(2, 2, 1)

# %%
plt.plot(mean_df, 'k--')
# Out:
# [<matplotlib.lines.Line2D at 0x10bc9b090>,
#  <matplotlib.lines.Line2D at 0x10bc9b390>,
#  <matplotlib.lines.Line2D at 0x10bc9b590>,
#  <matplotlib.lines.Line2D at 0x10bc9b750>,
#  <matplotlib.lines.Line2D at 0x10bc9b910>]

# %%
ax2=fig.add_subplot(2, 2, 2)

# %%
mean_df.plot( color='k', linestyle='dashed', marker='o')

# %%
plt.plot(mean_df, 'k--')
# Out:
# [<matplotlib.lines.Line2D at 0x10cb67e90>,
#  <matplotlib.lines.Line2D at 0x10cb761d0>,
#  <matplotlib.lines.Line2D at 0x10cb763d0>,
#  <matplotlib.lines.Line2D at 0x10cb76590>,
#  <matplotlib.lines.Line2D at 0x10cb76750>]

# %%
plt.plot(mean_df, 'k-')
# Out:
# [<matplotlib.lines.Line2D at 0x10bad0d90>,
#  <matplotlib.lines.Line2D at 0x10bade0d0>,
#  <matplotlib.lines.Line2D at 0x10bade2d0>,
#  <matplotlib.lines.Line2D at 0x10bade490>,
#  <matplotlib.lines.Line2D at 0x10bade650>]

# %%
df.resample('15min', how=np.max)
# Out:
#                                 power  current  voltage  phase_angle  \
#                                active
# 2012-06-01 02:00:00+02:00   21.576000   0.1656      236            0
# 2012-06-01 02:15:00+02:00   21.556999   0.1586      236            0
# 2012-06-01 02:30:00+02:00   21.561001   0.1749      236            0
# 2012-06-01 02:45:00+02:00   21.650999   0.1601      237            0
# 2012-06-01 03:00:00+02:00   21.552000   0.1645      236            0
# 2012-06-01 03:15:00+02:00   21.566000   0.1726      236            0
# 2012-06-01 03:30:00+02:00   21.698000   0.1590      236            0
# 2012-06-01 03:45:00+02:00   21.604000   0.1736      237            0
# 2012-06-01 04:00:00+02:00   21.656000   0.1639      237            0
# 2013-01-31 22:30:00+01:00   0.000000
# 2013-01-31 22:45:00+01:00   0.000000
# 2013-01-31 23:00:00+01:00   0.000000
# 2013-01-31 23:15:00+01:00   0.000000
# 2013-01-31 23:30:00+01:00   0.000000
# 2013-01-31 23:45:00+01:00   0.000000
# 2013-02-01 00:00:00+01:00   0.000000
# 2013-02-01 00:15:00+01:00   0.000000
# 2013-02-01 00:30:00+01:00   0.000000
# 2013-02-01 00:45:00+01:00   0.000000
#
# [23520 rows x 5 columns]

# %%
df_max=df.resample('15min', how=np.max)

# %%
df_min=df.resample('15min', how=np.min)

# %%
df_range=df_max - df_min

# %%
df_range
# Out:
#                                 power  current  voltage  phase_angle  \
#                                active
# 2012-06-01 02:00:00+02:00    1.040001   0.0140        1            0
# 2012-06-01 02:15:00+02:00    1.007000   0.0080        2            0
# 2012-06-01 02:30:00+02:00    0.837000   0.0207        2            0
# 2012-06-01 02:45:00+02:00    0.893999   0.0070        2            0
# 2012-06-01 03:00:00+02:00    0.875000   0.0112        3            0
# 2012-06-01 03:15:00+02:00    1.063000   0.0184        2            0
# 2012-06-01 03:30:00+02:00    0.969000   0.0057        1            0
# 2012-06-01 03:45:00+02:00    0.813999   0.0205        1            0
# 2012-06-01 04:00:00+02:00    0.979000   0.0110        2            0
# 2012-06-01 04:15:00+02:00    0.908001   0.0055        2            0
# 2012-06-01 04:30:00+02:00    0.945999   0.0223        2            0
# 2012-06-01 04:45:00+02:00    0.889002   0.0055        2            0
# 2012-06-01 05:00:00+02:00    0.790001   0.0195        1            0
# 2012-06-01 05:15:00+02:00    0.885000   0.0068        2            0
# 2012-06-01 05:30:00+02:00    0.851002   0.0051        2            0
# 2012-06-01 05:45:00+02:00    0.879999   0.0060        1            0
# 2012-06-01 06:00:00+02:00    1.007000   0.0132        1            0
# 2012-06-01 06:15:00+02:00    0.837002   0.0058        3            0
# 2012-06-01 06:30:00+02:00    1.021002   0.0055        2            0
# 2012-06-01 06:45:00+02:00    0.762001   0.0057        2            0
# 2012-06-01 07:00:00+02:00    0.837000   0.0104        3            0
# 2012-06-01 07:15:00+02:00    0.908001   0.0049        1            0
# 2012-06-01 07:30:00+02:00    0.710001   0.0140        2            0
# 2012-06-01 07:45:00+02:00    1.091000   0.0217        6            0
# 2012-06-01 08:00:00+02:00    1.078001   0.0207        4            0
# 2012-06-01 08:15:00+02:00    2.414000   0.0117        5            0
# 2012-06-01 08:30:00+02:00    2.385000   0.0105        3            0
# 2012-06-01 08:45:00+02:00    1.313000   0.0081        4            0
# 2012-06-01 09:00:00+02:00    1.115000   0.0239        3            0
# 2012-06-01 09:15:00+02:00    1.096001   0.0126        3            0
# ...                               ...      ...      ...          ...
# 2013-01-31 17:30:00+01:00    4.893005   0.0296        2            1
# 2013-01-31 17:45:00+01:00    5.251999   0.0315        2            1
# 2013-01-31 18:00:00+01:00    8.320007   0.0415        3            1
# 2013-01-31 18:15:00+01:00    6.003998   0.0384        2            1
# 2012-06-01 08:15:00+02:00   0.000000
# 2012-06-01 08:30:00+02:00   0.000000
# 2012-06-01 08:45:00+02:00   0.000000
# 2012-06-01 09:00:00+02:00   0.000000
# 2012-06-01 09:15:00+02:00   0.000000
# ...                              ...
# 2013-01-31 17:30:00+01:00   4.782850
# 2013-01-31 17:45:00+01:00   4.791807
# 2013-01-31 18:00:00+01:00   5.041340
# 2013-01-31 18:15:00+01:00   5.007057
# 2013-01-31 18:30:00+01:00   8.153622
# 2013-01-31 18:45:00+01:00  38.044334
# 2013-01-31 19:00:00+01:00   0.000000
# 2013-01-31 19:15:00+01:00   0.000000
# 2013-01-31 19:30:00+01:00   4.224079
# 2013-01-31 19:45:00+01:00   0.000000
# 2013-01-31 20:00:00+01:00   0.000000
# 2013-01-31 20:15:00+01:00   0.000000
# 2013-01-31 20:30:00+01:00   0.000000
# 2013-01-31 20:45:00+01:00   0.000000
# 2013-01-31 21:00:00+01:00   0.000000
# 2013-01-31 21:15:00+01:00   0.000000
# 2013-01-31 21:30:00+01:00   0.000000
# 2013-01-31 21:45:00+01:00   0.000000
# 2013-01-31 22:00:00+01:00   0.000000
# 2013-01-31 22:15:00+01:00   0.000000
# 2013-01-31 22:30:00+01:00   0.000000
# 2013-01-31 22:45:00+01:00   0.000000
# 2013-01-31 23:00:00+01:00   0.000000
# 2013-01-31 23:15:00+01:00   0.000000
# 2013-01-31 23:30:00+01:00   0.000000
# 2013-01-31 23:45:00+01:00   0.000000
# 2013-02-01 00:00:00+01:00   0.000000
# 2013-02-01 00:15:00+01:00   0.000000
# 2013-02-01 00:30:00+01:00   0.000000
# 2013-02-01 00:45:00+01:00   0.000000
#
# [23520 rows x 5 columns]

# %%
fig1=plt.figure()

# %%
ax1=fig.add_subplot(2, 2, 1)

# %%
ax2=fig.add_subplot(2, 2, 2)

# %%
ax3=fig.add_subplot(2, 2, 3)

# %%
plt.plot(df_max)
# Out:
# [<matplotlib.lines.Line2D at 0x10c8a2810>,
#  <matplotlib.lines.Line2D at 0x10d4b2450>,
#  <matplotlib.lines.Line2D at 0x10d4b2550>,
#  <matplotlib.lines.Line2D at 0x10d4b2910>,
#  <matplotlib.lines.Line2D at 0x10d4b2ad0>]

# %%
fig

# %%
ax2.plot(df_min)
# Out:
# [<matplotlib.lines.Line2D at 0x10d997e10>,
#  <matplotlib.lines.Line2D at 0x10d997650>,
#  <matplotlib.lines.Line2D at 0x10d997450>,
#  <matplotlib.lines.Line2D at 0x10b8ace50>,
#  <matplotlib.lines.Line2D at 0x10d95ea90>]

# %%
ax3.plot(df_range)
# Out:
# [<matplotlib.lines.Line2D at 0x10d95e2d0>,
#  <matplotlib.lines.Line2D at 0x10c0970d0>,
#  <matplotlib.lines.Line2D at 0x10d2206d0>,
#  <matplotlib.lines.Line2D at 0x10b293310>,
#  <matplotlib.lines.Line2D at 0x10d9c1f50>]

# %%
fig
